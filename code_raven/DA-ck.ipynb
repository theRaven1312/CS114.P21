# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

import seaborn as sns
from datetime import datetime
import json
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
ck = pd.read_csv('ck-public.csv')
annonimized = pd.read_csv('annonimized.csv')

print("Size of qt dataset:", ck.shape)
print("Size of annonimized dataset:", annonimized.shape)
# Out:
# Size of qt dataset: (761, 2)
# Size of annonimized dataset: (295198, 11)

# %%
print(f"\nNumber of unique students: {annonimized['concat(\'it001\', username)'].nunique()}")
print(f"Number of unique assignments: {annonimized['concat(\'it001\',`assignment_id`)'].nunique()}")
print(f"Number of unique problems: {annonimized['concat(\'it001\',`problem_id`)'].nunique()}")
# Out:
# Number of unique students: 1489
# Number of unique assignments: 203
# Number of unique problems: 469

# %%
import json

annonimized_extracted = annonimized[[
    "concat('it001',`assignment_id`)",
    "concat('it001',`problem_id`)",
    "concat('it001', username)",
    "is_final",
    "status",
    "coefficient",
    "pre_score",
    "created_at",
    "updated_at",
    "judgement"
]].copy()

annonimized_extracted.columns = [
    "assignment_id",
    "problem_id",
    "student",
    "is_final",
    "status",
    "late_coef",
    "score_percent",
    "submit_time",
    "grade_time",
    "judgement"
]

annonimized_extracted = annonimized_extracted[[
    "assignment_id",
    "problem_id",
    "student",
    "is_final",
    "status",
    "late_coef",
    "score_percent",
]]

annonimized_extracted.head()
# Out:
#                               assignment_id  \
# 0  90ce27571176d87961b565d5ef4b3de33ede04ac
# 1  90ce27571176d87961b565d5ef4b3de33ede04ac
# 2  90ce27571176d87961b565d5ef4b3de33ede04ac
# 3  90ce27571176d87961b565d5ef4b3de33ede04ac
# 4  90ce27571176d87961b565d5ef4b3de33ede04ac
#
#                                  problem_id  \
# 0  789454427dd4097a14749e3dde63346b7a8d3811
# 1  789454427dd4097a14749e3dde63346b7a8d3811
# 2  789454427dd4097a14749e3dde63346b7a8d3811
# 3  bf96fbdc5f499538c3e2bfbec5779c8a14b0a9ff
# 4  7a6e5ca470ff47c3b5048f240c4738de71010c78
#
#                                     student  is_final status  late_coef  \
# 0  ed9eaeb6a707f50154024b24d7efcb874a9795dd         0  SCORE        100
# 1  ed9eaeb6a707f50154024b24d7efcb874a9795dd         0  SCORE        100
# 2  ed9eaeb6a707f50154024b24d7efcb874a9795dd         1  SCORE        100
# 3  ed9eaeb6a707f50154024b24d7efcb874a9795dd         1  SCORE        100
# 4  ed9eaeb6a707f50154024b24d7efcb874a9795dd         1  SCORE        100
#
#    score_percent
# 0              0
# 1              0
# 2          10000
# 3          10000
# 4          10000

# %%
student_stats = annonimized_extracted.groupby('student').agg(
    num_submissions=('student', 'count'),  # Tổng số lần nộp bài
    num_score_100=('score_percent', lambda x: (x == 10000).sum()),  # Số lần đạt 100% testcase
    num_unique_problems=('problem_id', 'nunique'),  # Số bài tập unique đã làm
    num_unique_assignments=('assignment_id', 'nunique'),  # Số assignment unique đã làm
    avg_score_percent=('score_percent', 'mean'),  # Điểm trung bình các lần nộp
    avg_late_coef=('late_coef', 'mean'),  # Hệ số trễ trung bình
    num_final_submissions=('is_final', lambda x: (x == 1).sum()),  # Số lần nộp tính điểm
    total_status_ok=('status', lambda x: (x == "SCORE").sum()),  # Số lần code chạy được
).reset_index()

# Tính thêm các tỷ lệ
student_stats['ratio_score_100'] = student_stats['num_score_100'] / student_stats['num_submissions']
student_stats['ratio_final_submissions'] = student_stats['num_final_submissions'] / student_stats['num_submissions']
student_stats['ratio_status_ok'] = student_stats['total_status_ok'] / student_stats['num_submissions']
student_stats['avg_submissions_per_problem'] = student_stats['num_submissions'] / student_stats['num_unique_problems']

student_stats
# Out:
#                                        student  num_submissions  \
# 0     00b6dd4fc7eb817e03708c532016ef30ce564a61              147
# 1     00bef8afee8f3c595d535c9c03c490cac1a4f021              259
# 2     01122b3ef7e59b84189e65985305f575d6bdf83c              195
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183              100
# 4     013de369c439ab0ead8aa7da64423aa395a8be39              107
# ...                                        ...              ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627               74
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312              260
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076              437
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51               94
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359              399
#
#       num_score_100  num_unique_problems  num_unique_assignments  \
# 0                54                   46                       7
# 1                85                   78                       9
# 2                59                   66                       7
# 3                52                   47                       4
# 4                59                   52                       8
# ...             ...                  ...                     ...
# 1484             40                   34                       9
# 1485             80                   77                       6
# 1486            105                  100                       6
# 1487             30                   34                       7
# 1488            138                   96                      10
#
#       avg_score_percent  avg_late_coef  num_final_submissions  \
# 0           5504.149660     100.000000                     46
# 1           5488.552124     100.000000                     78
# 2           5973.753846     100.000000                     67
# 3           5952.760000     100.000000                     47
# 4           6474.448598      97.196262                     66
# ...                 ...            ...                    ...
# 1484        5581.081081     100.000000                     34
# 1485        6204.557692     100.000000                     78
# 1486        4998.466819     100.000000                    103
# 1487        4343.329787     100.000000                     34
# 1488        6353.769424     100.000000                     96
#
#       total_status_ok  ratio_score_100  ratio_final_submissions  \
# 0                 119         0.367347                 0.312925
# 1                 209         0.328185                 0.301158
# 2                 175         0.302564                 0.343590
# 3                  76         0.520000                 0.470000
# 4                  94         0.551402                 0.616822
# ...               ...              ...                      ...
# 1484               71         0.540541                 0.459459
# 1485              216         0.307692                 0.300000
# 1486              360         0.240275                 0.235698
# 1487               74         0.319149                 0.361702
# 1488              351         0.345865                 0.240602
#
#       ratio_status_ok  avg_submissions_per_problem
# 0            0.809524                     3.195652
# 1            0.806950                     3.320513
# 2            0.897436                     2.954545
# 3            0.760000                     2.127660
# 4            0.878505                     2.057692
# ...               ...                          ...
# 1484         0.959459                     2.176471
# 1485         0.830769                     3.376623
# 1486         0.823799                     4.370000
# 1487         0.787234                     2.764706
# 1488         0.879699                     4.156250
#
# [1489 rows x 13 columns]

# %%
ck['CK'] = pd.to_numeric(ck['CK'], errors='coerce')
ck
# Out:
#                                          hash   CK
# 0    00b6dd4fc7eb817e03708c532016ef30ce564a61  5.5
# 1    00bef8afee8f3c595d535c9c03c490cac1a4f021  6.5
# 2    01122b3ef7e59b84189e65985305f575d6bdf83c  4.5
# 3    013de369c439ab0ead8aa7da64423aa395a8be39  5.0
# 4    014c59c6433fd764a0b08de6ffeb757eaf60aa73  4.0
# ..                                        ...  ...
# 756  840d07858c03f80f4695056e2cc7d0c474b83a25  5.5
# 757  844f5db2e7e31ae51eba025480679ed7e4708ac6  6.0
# 758  845acd04a77b3d1b623f255d9f9f8eae90892dab  6.0
# 759  8460eaaf887a6289fb156f7562fb739ba8e9629e  7.0
# 760  8481a7f00c3d30473b01a8a3cff2564948d24902  2.5
#
# [761 rows x 2 columns]

# %%
student_stats_merged = student_stats.merge(ck[['hash', 'CK']], how='left', left_on='student', right_on='hash')
student_stats_merged = student_stats_merged.drop(columns=['hash'])

student_stats_merged
# Out:
#                                        student  num_submissions  \
# 0     00b6dd4fc7eb817e03708c532016ef30ce564a61              147
# 1     00bef8afee8f3c595d535c9c03c490cac1a4f021              259
# 2     01122b3ef7e59b84189e65985305f575d6bdf83c              195
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183              100
# 4     013de369c439ab0ead8aa7da64423aa395a8be39              107
# ...                                        ...              ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627               74
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312              260
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076              437
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51               94
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359              399
#
#       num_score_100  num_unique_problems  num_unique_assignments  \
# 0                54                   46                       7
# 1                85                   78                       9
# 2                59                   66                       7
# 3                52                   47                       4
# 4                59                   52                       8
# ...             ...                  ...                     ...
# 1484             40                   34                       9
# 1485             80                   77                       6
# 1486            105                  100                       6
# 1487             30                   34                       7
# 1488            138                   96                      10
#
#       avg_score_percent  avg_late_coef  num_final_submissions  \
# 0           5504.149660     100.000000                     46
# 1           5488.552124     100.000000                     78
# 2           5973.753846     100.000000                     67
# 3           5952.760000     100.000000                     47
# 4           6474.448598      97.196262                     66
# ...                 ...            ...                    ...
# 1484        5581.081081     100.000000                     34
# 1485        6204.557692     100.000000                     78
# 1486        4998.466819     100.000000                    103
# 1487        4343.329787     100.000000                     34
# 1488        6353.769424     100.000000                     96
#
#       total_status_ok  ratio_score_100  ratio_final_submissions  \
# 0                 119         0.367347                 0.312925
# 1                 209         0.328185                 0.301158
# 2                 175         0.302564                 0.343590
# 3                  76         0.520000                 0.470000
# 4                  94         0.551402                 0.616822
# ...               ...              ...                      ...
# 1484               71         0.540541                 0.459459
# 1485              216         0.307692                 0.300000
# 1486              360         0.240275                 0.235698
# 1487               74         0.319149                 0.361702
# 1488              351         0.345865                 0.240602
#
#       ratio_status_ok  avg_submissions_per_problem   CK
# 0            0.809524                     3.195652  5.5
# 1            0.806950                     3.320513  6.5
# 2            0.897436                     2.954545  4.5
# 3            0.760000                     2.127660  NaN
# 4            0.878505                     2.057692  5.0
# ...               ...                          ...  ...
# 1484         0.959459                     2.176471  NaN
# 1485         0.830769                     3.376623  NaN
# 1486         0.823799                     4.370000  NaN
# 1487         0.787234                     2.764706  NaN
# 1488         0.879699                     4.156250  NaN
#
# [1489 rows x 14 columns]

# %%
graded = student_stats_merged[student_stats_merged['CK'].notnull()].copy()
ungraded = student_stats_merged[student_stats_merged['CK'].isnull()].copy()

# %%
graded
# Out:
#                                       student  num_submissions  num_score_100  \
# 0    00b6dd4fc7eb817e03708c532016ef30ce564a61              147             54
# 1    00bef8afee8f3c595d535c9c03c490cac1a4f021              259             85
# 2    01122b3ef7e59b84189e65985305f575d6bdf83c              195             59
# 4    013de369c439ab0ead8aa7da64423aa395a8be39              107             59
# 5    014c59c6433fd764a0b08de6ffeb757eaf60aa73              199             79
# ..                                        ...              ...            ...
# 796  840d07858c03f80f4695056e2cc7d0c474b83a25              111             41
# 797  844f5db2e7e31ae51eba025480679ed7e4708ac6              357            108
# 798  845acd04a77b3d1b623f255d9f9f8eae90892dab              155             47
# 799  8460eaaf887a6289fb156f7562fb739ba8e9629e              557            113
# 800  8481a7f00c3d30473b01a8a3cff2564948d24902               54             23
#
#      num_unique_problems  num_unique_assignments  avg_score_percent  \
# 0                     46                       7        5504.149660
# 1                     78                       9        5488.552124
# 2                     66                       7        5973.753846
# 4                     52                       8        6474.448598
# 5                     90                       9        5240.025126
# ..                   ...                     ...                ...
# 796                   43                       6        5171.639640
# 797                  104                      17        4785.224090
# 798                   52                       8        4247.296774
# 799                  114                      12        4278.605027
# 800                   24                       4        4444.444444
#
#      avg_late_coef  num_final_submissions  total_status_ok  ratio_score_100  \
# 0       100.000000                     46              119         0.367347
# 1       100.000000                     78              209         0.328185
# 2       100.000000                     67              175         0.302564
# 4        97.196262                     66               94         0.551402
# 5       100.000000                     90              154         0.396985
# ..             ...                    ...              ...              ...
# 796     100.000000                     44               81         0.369369
# 797     100.000000                    104              254         0.302521
# 798     100.000000                     53              117         0.303226
# 799     100.000000                    115              416         0.202873
# 800     100.000000                     24               35         0.425926
#
#      ratio_final_submissions  ratio_status_ok  avg_submissions_per_problem  \
# 0                   0.312925         0.809524                     3.195652
# 1                   0.301158         0.806950                     3.320513
# 2                   0.343590         0.897436                     2.954545
# 4                   0.616822         0.878505                     2.057692
# 5                   0.452261         0.773869                     2.211111
# ..                       ...              ...                          ...
# 796                 0.396396         0.729730                     2.581395
# 797                 0.291317         0.711485                     3.432692
# 798                 0.341935         0.754839                     2.980769
# 799                 0.206463         0.746858                     4.885965
# 800                 0.444444         0.648148                     2.250000
#
#       CK
# 0    5.5
# 1    6.5
# 2    4.5
# 4    5.0
# 5    4.0
# ..   ...
# 796  5.5
# 797  6.0
# 798  6.0
# 799  7.0
# 800  2.5
#
# [755 rows x 14 columns]

# %%
ungraded
# Out:
#                                        student  num_submissions  \
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183              100
# 20    035f97702f2c01d26ab1fae8f39ea2f98a0caa3c              144
# 40    06024da8147b5cf6105beb4c403f67cf1ff0aea1                8
# 68    0aaebc88f6106684d6993c156104c1ef36cf94e0              192
# 80    0bf111a9caedf02804f6991792490e63bc21058a              199
# ...                                        ...              ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627               74
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312              260
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076              437
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51               94
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359              399
#
#       num_score_100  num_unique_problems  num_unique_assignments  \
# 3                52                   47                       4
# 20               52                   50                       4
# 40                5                    5                       1
# 68               53                   50                       4
# 80               79                   65                       6
# ...             ...                  ...                     ...
# 1484             40                   34                       9
# 1485             80                   77                       6
# 1486            105                  100                       6
# 1487             30                   34                       7
# 1488            138                   96                      10
#
#       avg_score_percent  avg_late_coef  num_final_submissions  \
# 3           5952.760000          100.0                     47
# 20          5035.763889          100.0                     50
# 40          6778.750000          100.0                      5
# 68          4065.369792          100.0                     50
# 80          6355.753769          100.0                     82
# ...                 ...            ...                    ...
# 1484        5581.081081          100.0                     34
# 1485        6204.557692          100.0                     78
# 1486        4998.466819          100.0                    103
# 1487        4343.329787          100.0                     34
# 1488        6353.769424          100.0                     96
#
#       total_status_ok  ratio_score_100  ratio_final_submissions  \
# 3                  76         0.520000                 0.470000
# 20                103         0.361111                 0.347222
# 40                  8         0.625000                 0.625000
# 68                149         0.276042                 0.260417
# 80                176         0.396985                 0.412060
# ...               ...              ...                      ...
# 1484               71         0.540541                 0.459459
# 1485              216         0.307692                 0.300000
# 1486              360         0.240275                 0.235698
# 1487               74         0.319149                 0.361702
# 1488              351         0.345865                 0.240602
#
#       ratio_status_ok  avg_submissions_per_problem  CK
# 3            0.760000                     2.127660 NaN
# 20           0.715278                     2.880000 NaN
# 40           1.000000                     1.600000 NaN
# 68           0.776042                     3.840000 NaN
# 80           0.884422                     3.061538 NaN
# ...               ...                          ...  ..
# 1484         0.959459                     2.176471 NaN
# 1485         0.830769                     3.376623 NaN
# 1486         0.823799                     4.370000 NaN
# 1487         0.787234                     2.764706 NaN
# 1488         0.879699                     4.156250 NaN
#
# [734 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = graded.drop(columns=['student', 'CK'])
y = graded['CK'].astype(float)  


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


lr = LinearRegression()
lr.fit(X_train, y_train)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)


print("Model score (R^2):", lr.score(X_test, y_test))

plt.scatter(y_test, lr.predict(X_test), alpha=0.5)
plt.xlabel('Actual CK')
plt.ylabel('Predicted CK')
plt.title('Predicted vs Actual CK')
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--') 
plt.show()

print("Random Forest Model score (R^2):", rf.score(X_test, y_test))
plt.scatter(y_test, rf.predict(X_test), alpha=0.5)
plt.xlabel('Actual CK')
plt.ylabel('Predicted CK (RF)')
plt.title('Predicted vs Actual CK (RF)')
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.show()
# Out:
# Model score (R^2): 0.22289218117069842
# Random Forest Model score (R^2): 0.15223708113755818

# %%
X_predict = scaler.transform(ungraded.drop(columns=['student', 'CK']))

predictions = rf.predict(X_predict)

predict_ungraded = ungraded.copy()
predict_ungraded['CK'] = predictions

predict_ungraded
# Out:
#                                        student  num_submissions  \
# 3     0134f9f410c65ad0e8c2254a7e9288670e02a183              100
# 20    035f97702f2c01d26ab1fae8f39ea2f98a0caa3c              144
# 40    06024da8147b5cf6105beb4c403f67cf1ff0aea1                8
# 68    0aaebc88f6106684d6993c156104c1ef36cf94e0              192
# 80    0bf111a9caedf02804f6991792490e63bc21058a              199
# ...                                        ...              ...
# 1484  feb8a2859a011c59efd22ed419cb69288fe03627               74
# 1485  fef4a3263ed9a8ab14d457694bb8fd86ccd98312              260
# 1486  ff12d6e2ab80696ed8e22fbe5497e96c68d29076              437
# 1487  ff3fa2ec64294f37ae968159f810ebeda7966c51               94
# 1488  ffe872165621d735a48bb5db0c71dd5195cba359              399
#
#       num_score_100  num_unique_problems  num_unique_assignments  \
# 3                52                   47                       4
# 20               52                   50                       4
# 40                5                    5                       1
# 68               53                   50                       4
# 80               79                   65                       6
# ...             ...                  ...                     ...
# 1484             40                   34                       9
# 1485             80                   77                       6
# 1486            105                  100                       6
# 1487             30                   34                       7
# 1488            138                   96                      10
#
#       avg_score_percent  avg_late_coef  num_final_submissions  \
# 3           5952.760000          100.0                     47
# 20          5035.763889          100.0                     50
# 40          6778.750000          100.0                      5
# 68          4065.369792          100.0                     50
# 80          6355.753769          100.0                     82
# ...                 ...            ...                    ...
# 1484        5581.081081          100.0                     34
# 1485        6204.557692          100.0                     78
# 1486        4998.466819          100.0                    103
# 1487        4343.329787          100.0                     34
# 1488        6353.769424          100.0                     96
#
#       total_status_ok  ratio_score_100  ratio_final_submissions  \
# 3                  76         0.520000                 0.470000
# 20                103         0.361111                 0.347222
# 40                  8         0.625000                 0.625000
# 68                149         0.276042                 0.260417
# 80                176         0.396985                 0.412060
# ...               ...              ...                      ...
# 1484               71         0.540541                 0.459459
# 1485              216         0.307692                 0.300000
# 1486              360         0.240275                 0.235698
# 1487               74         0.319149                 0.361702
# 1488              351         0.345865                 0.240602
#
#       ratio_status_ok  avg_submissions_per_problem     CK
# 3            0.760000                     2.127660  3.600
# 20           0.715278                     2.880000  5.110
# 40           1.000000                     1.600000  7.395
# 68           0.776042                     3.840000  5.325
# 80           0.884422                     3.061538  6.060
# ...               ...                          ...    ...
# 1484         0.959459                     2.176471  6.275
# 1485         0.830769                     3.376623  5.630
# 1486         0.823799                     4.370000  5.490
# 1487         0.787234                     2.764706  5.180
# 1488         0.879699                     4.156250  6.950
#
# [734 rows x 14 columns]

# %%
predict_ungraded = predict_ungraded[['student', 'CK']]

predict_ungraded.to_csv('predicted_ck.csv', index=False)
